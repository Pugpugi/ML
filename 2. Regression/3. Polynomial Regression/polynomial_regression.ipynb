# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Position_Salaries.csv')
x = dataset.iloc[:, 1:-1].values # use 1:-1 as regression method expects 2D array and using just 1 for the middle row makes it a 1D arrary 
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures 
poly_reg = PolynomialFeatures(degree = 5)
x_poly = poly_reg.fit_transform(x)
regressor_2 = LinearRegression()
regressor_2.fit(x_poly, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
plt.scatter(x, y, color = 'red')
plt.plot(x, regressor.predict(x), color = 'blue')
plt.title('Linear Regression')
plt.xlabel("Position level")
plt.ylabel("Salary")
plt.show()

# visualize why linear model is not suitable for polynomial model

# %% [markdown]
# ## Visualising the Polynomial Regression results

# %%
plt.scatter(x, y, color = 'red')
plt.plot(x, regressor_2.predict(x_poly), color = 'blue')
plt.title('Linear Regression') 
plt.xlabel("Position level")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
regressor.predict([[6.5]])
# Out:
# array([330378.78787879])

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
regressor_2.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# array([174878.07765173])
